# %% [markdown]
# What is node?
#
# item-30     item-32     item-20
#
# we need to maintain sequence (we can make refernce varibale )-> next
#
# class bana lenge Node -- [item,next]  [item,next]  [item,next]
#
#                           30            32           20
